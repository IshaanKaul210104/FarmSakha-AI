# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image

model = tf.keras.models.load_model("Models/potato_model.h5", compile=False)

# Define labels manually (PlantVillage standard)
class_labels = ["Early Blight", "Late Blight", "Healthy"]

# Preprocess input
img = image.load_img("testimages/N1.jpg", target_size=(256,256))
img_array = image.img_to_array(img)/255.0
img_array = np.expand_dims(img_array, axis=0)

# Predict
pred = model.predict(img_array)
pred_class = np.argmax(pred, axis=1)[0]
print("Predicted disease:", class_labels[pred_class])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Ishaan Kaul\Desktop\PROJECTS\FarmSakha_AI\venv\Lib\site-packages\keras\src\ops\operation.py:255, in Operation.from_config(cls, config)
#     254 try:
# --> 255     return cls(**config)
#     256 except Exception as e:
#
# File c:\Users\Ishaan Kaul\Desktop\PROJECTS\FarmSakha_AI\venv\Lib\site-packages\keras\src\layers\convolutional\conv2d.py:118, in Conv2D.__init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#      98 def __init__(
#      99     self,
#     100     filters,
#    (...)    116     **kwargs,
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         filters=filters,
# ...
